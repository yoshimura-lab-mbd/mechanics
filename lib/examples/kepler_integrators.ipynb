# %%
# %matplotlib widget
# %reset -f
# %load_ext autoreload
# %autoreload 1
# %aimport mechanics

from sympy import *
from mechanics import *
from mechanics.lagrange import euler_lagrange_equation
import mechanics.space as space

t, = base_spaces('t')
def dot(f): return diff(f, t)

r, = variables('r', t)
theta, = variables(r'\theta', t, space=space.S)
q = r, theta
dq = tuple(dot(q_n) for q_n in q)
ddq = tuple(dot(dq_n) for dq_n in dq)

mu, m = constants(r'\mu m')

x = r * cos(theta)
y = r * sin(theta)

U = - mu / r
T = (m / 2 * (dot(x)**2 + dot(y)**2)).simplify()
E = T + U
L = T - U
show('L =' , L)


EL = euler_lagrange_equation(L, q)
show_equations(EL)

F = solve(EL, ddq)
show_equations(F)
# Out:
# $\displaystyle L =\frac{\left({{r}}^2 \dot{{\theta}}^{2} + \dot{{r}}^{2}\right) {m}}{2} + \frac{{\mu}}{{r}}$
# $\displaystyle \begin{cases}- \frac{{\mu}}{{{r}}^2} + {m} {r} \dot{{\theta}}^{2} - {m} \ddot{{r}} = 0\\- {m} {{r}}^2 \ddot{{\theta}} - 2 {m} {r} \dot{{\theta}} \dot{{r}} = 0\\\end{cases}$
# $\displaystyle \begin{cases}\ddot{{\theta}} = - \frac{2 \dot{{\theta}} \dot{{r}}}{{r}}\\\ddot{{r}} = - \frac{{\mu}}{{m} {{r}}^2} + {r} \dot{{\theta}}^{2}\\\end{cases}$

# %%
# %autoreload

from mechanics.integrator.euler import euler_explicit, backward_euler_explicit, heun_explicit
from mechanics.integrator.runge_kutta import rk4_explicit

h, T = constants('h T')
i, = indices('i')

euler_X, euler_step, d = euler_explicit(F, h, i)
print('Euler method:')
show_equations(euler_step)

b_euler_X, b_euler_V, b_euler_step, d = backward_euler_explicit(F, h, i)
print('Backward Euler method:')
show_equations(b_euler_step)

heun_X, heun_K, heun_step, d = heun_explicit(F, h, i)
print('Heun\'s method:')
show_equations(heun_step)

rk4_X, rk4_K, rk4_step, d = rk4_explicit(F, h, i)
print('Runge-Kutta 4:')
show_equations(rk4_step)

r, theta = d(q)
v_r, v_theta = d(dq)
# Out:
# Euler method:
# $\displaystyle \begin{cases}{v_{\theta}}_{i + 1} = - \frac{2 {h} {v_{\theta}}_{i} {v_{r}}_{i}}{{r}_{i}} + {v_{\theta}}_{i}\\{v_{r}}_{i + 1} = \left(- \frac{{\mu}}{{m} {{r}_{i}}^2} + {r}_{i} {{v_{\theta}}_{i}}^2\right) {h} + {v_{r}}_{i}\\{\theta}_{i + 1} = {\theta}_{i} + {h} {v_{\theta}}_{i}\\{r}_{i + 1} = {h} {v_{r}}_{i} + {r}_{i}\\\end{cases}$
# Backward Euler method:
# $\displaystyle \begin{cases}\frac{2 {h} {v_{\theta}}_{i + 1} {v_{r}}_{i + 1}}{{r}_{i + 1}} - {v_{\theta}}_{i} + {v_{\theta}}_{i + 1} = 0\\- \left(- \frac{{\mu}}{{m} {{r}_{i + 1}}^2} + {r}_{i + 1} {{v_{\theta}}_{i + 1}}^2\right) {h} - {v_{r}}_{i} + {v_{r}}_{i + 1} = 0\\- {\theta}_{i} + {\theta}_{i + 1} - {h} {v_{\theta}}_{i + 1} = 0\\- {h} {v_{r}}_{i + 1} - {r}_{i} + {r}_{i + 1} = 0\\\end{cases}$
# Heun's method:
# $\displaystyle \begin{cases}{k_{v_{\theta}}}_{i} = - \frac{2 {h} {v_{\theta}}_{i} {v_{r}}_{i}}{{r}_{i}}\\{k_{v_{r}}}_{i} = \left(- \frac{{\mu}}{{m} {{r}_{i}}^2} + {r}_{i} {{v_{\theta}}_{i}}^2\right) {h}\\{k_{\theta}}_{i} = {h} {v_{\theta}}_{i}\\{k_{r}}_{i} = {h} {v_{r}}_{i}\\{v_{\theta}}_{i + 1} = \frac{{k_{v_{\theta}}}_{i}}{2} + {v_{\theta}}_{i} - \frac{\left({k_{v_{\theta}}}_{i} + {v_{\theta}}_{i}\right) \left({k_{v_{r}}}_{i} + {v_{r}}_{i}\right) {h}}{{k_{r}}_{i} + {r}_{i}}\\{v_{r}}_{i + 1} = \frac{\left(\left({k_{r}}_{i} + {r}_{i}\right) \left({k_{v_{\theta}}}_{i} + {v_{\theta}}_{i}\right)^{2} - \frac{{\mu}}{\left({k_{r}}_{i} + {r}_{i}\right)^{2} {m}}\right) {h}}{2} + \frac{{k_{v_{r}}}_{i}}{2} + {v_{r}}_{i}\\{\theta}_{i + 1} = \frac{\left({k_{v_{\theta}}}_{i} + {v_{\theta}}_{i}\right) {h}}{2} + {\theta}_{i} + \frac{{k_{\theta}}_{i}}{2}\\{r}_{i + 1} = \frac{\left({k_{v_{r}}}_{i} + {v_{r}}_{i}\right) {h}}{2} + \frac{{k_{r}}_{i}}{2} + {r}_{i}\\\end{cases}$
# Runge-Kutta 4:
# $\displaystyle \begin{cases}{k_{1, v_{\theta}}}_{i} = - \frac{2 {h} {v_{\theta}}_{i} {v_{r}}_{i}}{{r}_{i}}\\{k_{1, v_{r}}}_{i} = \left(- \frac{{\mu}}{{m} {{r}_{i}}^2} + {r}_{i} {{v_{\theta}}_{i}}^2\right) {h}\\{k_{1, \theta}}_{i} = {h} {v_{\theta}}_{i}\\{k_{1, r}}_{i} = {h} {v_{r}}_{i}\\{k_{2, v_{\theta}}}_{i} = - \frac{2 \left(\frac{{k_{1, v_{\theta}}}_{i}}{2} + {v_{\theta}}_{i}\right) \left(\frac{{k_{1, v_{r}}}_{i}}{2} + {v_{r}}_{i}\right) {h}}{\frac{{k_{1, r}}_{i}}{2} + {r}_{i}}\\{k_{2, v_{r}}}_{i} = \left(\left(\frac{{k_{1, r}}_{i}}{2} + {r}_{i}\right) \left(\frac{{k_{1, v_{\theta}}}_{i}}{2} + {v_{\theta}}_{i}\right)^{2} - \frac{{\mu}}{\left(\frac{{k_{1, r}}_{i}}{2} + {r}_{i}\right)^{2} {m}}\right) {h}\\{k_{2, \theta}}_{i} = \left(\frac{{k_{1, v_{\theta}}}_{i}}{2} + {v_{\theta}}_{i}\right) {h}\\{k_{2, r}}_{i} = \left(\frac{{k_{1, v_{r}}}_{i}}{2} + {v_{r}}_{i}\right) {h}\\{k_{3, v_{\theta}}}_{i} = - \frac{2 \left(\frac{{k_{2, v_{\theta}}}_{i}}{2} + {v_{\theta}}_{i}\right) \left(\frac{{k_{2, v_{r}}}_{i}}{2} + {v_{r}}_{i}\right) {h}}{\frac{{k_{2, r}}_{i}}{2} + {r}_{i}}\\{k_{3, v_{r}}}_{i} = \left(\left(\frac{{k_{2, r}}_{i}}{2} + {r}_{i}\right) \left(\frac{{k_{2, v_{\theta}}}_{i}}{2} + {v_{\theta}}_{i}\right)^{2} - \frac{{\mu}}{\left(\frac{{k_{2, r}}_{i}}{2} + {r}_{i}\right)^{2} {m}}\right) {h}\\{k_{3, \theta}}_{i} = \left(\frac{{k_{2, v_{\theta}}}_{i}}{2} + {v_{\theta}}_{i}\right) {h}\\{k_{3, r}}_{i} = \left(\frac{{k_{2, v_{r}}}_{i}}{2} + {v_{r}}_{i}\right) {h}\\{v_{\theta}}_{i + 1} = \frac{{k_{1, v_{\theta}}}_{i}}{6} + \frac{{k_{2, v_{\theta}}}_{i}}{3} + \frac{{k_{3, v_{\theta}}}_{i}}{3} + {v_{\theta}}_{i} - \frac{\left({k_{3, v_{\theta}}}_{i} + {v_{\theta}}_{i}\right) \left({k_{3, v_{r}}}_{i} + {v_{r}}_{i}\right) {h}}{3 \left({k_{3, r}}_{i} + {r}_{i}\right)}\\{v_{r}}_{i + 1} = \frac{\left(\left({k_{3, r}}_{i} + {r}_{i}\right) \left({k_{3, v_{\theta}}}_{i} + {v_{\theta}}_{i}\right)^{2} - \frac{{\mu}}{\left({k_{3, r}}_{i} + {r}_{i}\right)^{2} {m}}\right) {h}}{6} + \frac{{k_{1, v_{r}}}_{i}}{6} + \frac{{k_{2, v_{r}}}_{i}}{3} + \frac{{k_{3, v_{r}}}_{i}}{3} + {v_{r}}_{i}\\{\theta}_{i + 1} = \frac{\left({k_{3, v_{\theta}}}_{i} + {v_{\theta}}_{i}\right) {h}}{6} + {\theta}_{i} + \frac{{k_{1, \theta}}_{i}}{6} + \frac{{k_{2, \theta}}_{i}}{3} + \frac{{k_{3, \theta}}_{i}}{3}\\{r}_{i + 1} = \frac{\left({k_{3, v_{r}}}_{i} + {v_{r}}_{i}\right) {h}}{6} + \frac{{k_{1, r}}_{i}}{6} + \frac{{k_{2, r}}_{i}}{3} + \frac{{k_{3, r}}_{i}}{3} + {r}_{i}\\\end{cases}$

# %%
# %autoreload

solvers = {}

solver = build_solver()
solver.constants(mu, m, h, T)
solver.variables(*euler_X, index=(i, 0, T/h))
solver.functions('x', 'y', 'E', index=(i, 0, T/h))
solver.inputs(*(x[0] for x in euler_X))
with solver.steps(i, 0, T/h) as step:
    step.explicit(euler_step)
    step.calculate({'x': d(x), 'y': d(y), 'E': d(E)}, i)
solvers['Euler'] = solver.generate()

solver = build_solver()
solver.constants(mu, m, h, T)
solver.variables(*b_euler_X, index=(i, 0, T/h))
solver.functions('x', 'y', 'E', index=(i, 0, T/h))
solver.inputs(*(x[0] for x in b_euler_X))
with solver.steps(i, 0, T/h) as step:
    with step.newton() as newton:
        newton.unknowns(*b_euler_V)
        newton.initial_guess({v: v.subs(i, i-1) for v in b_euler_V})
        newton.implicit(b_euler_step)
    step.calculate({'x': d(x), 'y': d(y), 'E': d(E)}, i)
solvers['Backward Euler'] = solver.generate()

solver = build_solver()
solver.constants(mu, m, h, T)
solver.variables(*heun_X, *heun_K, index=(i, 0, T/h))
solver.functions('x', 'y', 'E', index=(i, 0, T/h))
solver.inputs(*(x[0] for x in heun_X))
with solver.steps(i, 0, T/h) as step:
    step.explicit(heun_step)
    step.calculate({'x': d(x), 'y': d(y), 'E': d(E)}, i)
solvers['Heun'] = solver.generate()

solver = build_solver()
solver.constants(mu, m, h, T)
solver.variables(*rk4_X, *rk4_K, index=(i, 0, T/h))
solver.functions('x', 'y', 'E', index=(i, 0, T/h))
solver.inputs(*(x[0] for x in rk4_X))
with solver.steps(i, 0, T/h) as step:
    step.explicit(rk4_step)
    step.calculate({'x': d(x), 'y': d(y), 'E': d(E)}, i)
solvers['RK4'] = solver.generate()
# Out:
# Generating Fortran code in /var/folders/4n/_jcnzrss7571s_0zzmtzqtsr0000gn/T/tmpyrv4jujm/generated.f90
# Generating Fortran code in /var/folders/4n/_jcnzrss7571s_0zzmtzqtsr0000gn/T/tmpdk0yaf5j/generated.f90
# Generating Fortran code in /var/folders/4n/_jcnzrss7571s_0zzmtzqtsr0000gn/T/tmpt3g9toip/generated.f90
# Generating Fortran code in /var/folders/4n/_jcnzrss7571s_0zzmtzqtsr0000gn/T/tmpnxp5u0eq/generated.f90

# %%
# %autoreload
results = {
    name: solver.run({
        mu: 1.0, m: 1.0, 
        h: 0.2, T: 100.0,
        r[0]: 1.0, theta[0]: 0.0,
        v_r[0]: 0.0, v_theta[0]: 1.1,
    }) for name, solver in solvers.items()
}
# Out:
# Warning: Calculation result is NaN in explicit equation: v_{\theta}(i + 1) = -2*h*v_{\theta}(i,)*v_{r}(i,)/r(i,) + v_{\theta}(i,).
# Log data in: /var/folders/4n/_jcnzrss7571s_0zzmtzqtsr0000gn/T/tmpvml21d_7/result.log, size=3511
# Log data in: /var/folders/4n/_jcnzrss7571s_0zzmtzqtsr0000gn/T/tmpb07xj67o/result.log, size=3511
# Log data in: /var/folders/4n/_jcnzrss7571s_0zzmtzqtsr0000gn/T/tmp2emifhnk/result.log, size=5515
# Log data in: /var/folders/4n/_jcnzrss7571s_0zzmtzqtsr0000gn/T/tmppfk3mqc8/result.log, size=9523

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['mathtext.fontset'] = 'cm'

t = np.arange(0, results['RK4'][T], results['RK4'][h])

fig, ax = plt.subplots(1, 1, figsize=(4, 4), tight_layout=True)
ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_aspect('equal')
ax.set_xlim(-2, 2)
ax.set_ylim(-2, 2)
for method, _ in results.items():
    ax.plot(_['x'], _['y'], label=method)
ax.legend()

fig, axes = plt.subplots(3, 2, figsize=(6, 8), tight_layout=True)
variables = [r, theta, v_r, v_theta, 'E']
for ax, var in zip(axes.flatten(), variables):
    name = getattr(var, 'name', var)
    ax.set_xlabel('$t$')
    ax.set_ylabel(f'${name}$')
    ax.set_xlim(0, results['RK4'][T])
    value_range = results['RK4'][var][:-1].max() - results['RK4'][var][:-1].min()
    value_center = (results['RK4'][var][:-1].max() + results['RK4'][var][:-1].min()) / 2
    ax.set_ylim(value_center - value_range, value_center + value_range)
    for method, _ in results.items():
        ax.plot(t, _[var][:-1], label=method)
    ax.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
