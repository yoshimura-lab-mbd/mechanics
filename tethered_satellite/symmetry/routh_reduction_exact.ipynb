# %% [markdown]
# ![](../figure/dumbbell_2d.svg)

# %%
# %matplotlib widget
# %reset -f
# %load_ext autoreload
# %autoreload 1
# %aimport mechanics

from sympy import *
from mechanics import *
import mechanics.space as space

t, = base_spaces('t')
def dot(f): return diff(f, t)

# Generalized coordinates
r, = variables('r', t)
theta, psi = variables(r'\theta, \psi', t, space=space.S)

q = r, theta, psi
dq = tuple(dot(q_n) for q_n in q)
ddq = tuple(dot(dq_n) for dq_n in dq)

# Parameters
# mu: gravitational constant of central body
# m: mass of dumbbell satellite
# I: moment of inertia of dumbbell satellite about mass center
# l: length of dumbbell satellite
mu, m, I, l = constants(r'\mu m I \ell')

# l = solve(I - m*l**2/4, l)[0]
I = m*l**2/4

x1 = r * cos(theta)
x2 = r * sin(theta)
v1 = dot(x1)
v2 = dot(x2)

# Position of two masses
x_a1 = x1 + l/2 * cos(theta + psi)
x_a2 = x2 + l/2 * sin(theta + psi)
x_b1 = x1 - l/2 * cos(theta + psi)
x_b2 = x2 - l/2 * sin(theta + psi)

r1 = sqrt(x_a1**2 + x_a2**2)
r2 = sqrt(x_b1**2 + x_b2**2)

# Lagrangian
U = (- mu * m/2 * (1/r1 + 1/r2)).simplify()
T = (m/2/2 * (dot(x_a1)**2 + dot(x_a2)**2) + m/2/2 * (dot(x_b1)**2 + dot(x_b2)**2)).simplify()
E = T + U
L = T - U
show('U =', U)
show('T =', T)
show('L =' , L)

def metric(v1, v2):
    return sum(diff(L, dq1_n, dq2_n) * v1_n * v2_n 
                for dq1_n, v1_n in zip(dq, v1) for dq2_n, v2_n in zip(dq, v2))

show(r'\|v\|^2 =', metric(dq, dq))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# $\displaystyle U =- \left(\frac{1}{\sqrt{{{\ell}}^2 + 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} + \frac{1}{\sqrt{{{\ell}}^2 - 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}}\right) {\mu} {m}$
# $\displaystyle T =\frac{\left({{\ell}}^2 \dot{{\psi}}^{2} + 2 {{\ell}}^2 \dot{{\psi}} \dot{{\theta}} + {{\ell}}^2 \dot{{\theta}}^{2} + 4 {{r}}^2 \dot{{\theta}}^{2} + 4 \dot{{r}}^{2}\right) {m}}{8}$
# $\displaystyle L =\left(\frac{1}{\sqrt{{{\ell}}^2 + 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} + \frac{1}{\sqrt{{{\ell}}^2 - 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}}\right) {\mu} {m} + \frac{\left({{\ell}}^2 \dot{{\psi}}^{2} + 2 {{\ell}}^2 \dot{{\psi}} \dot{{\theta}} + {{\ell}}^2 \dot{{\theta}}^{2} + 4 {{r}}^2 \dot{{\theta}}^{2} + 4 \dot{{r}}^{2}\right) {m}}{8}$
# $\displaystyle \|v\|^2 =\left(\frac{{{\ell}}^2}{4} + {{r}}^2\right) {m} \dot{{\theta}}^{2} + \frac{{{\ell}}^2 {m} \dot{{\psi}}^{2}}{4} + \frac{{{\ell}}^2 {m} \dot{{\psi}} \dot{{\theta}}}{2} + {m} \dot{{r}}^{2}$

# %%
I_lock = I + m*r**2
show(r'\mathbb{I} =', I_lock)

J_L = diff(L, dot(theta)).simplify()
show(r'J_\mathrm{L} =', J_L)

A = (J_L / I_lock)
show(r'\mathcal{A} =', A)

y = (r, psi)
dy = (dot(r), dot(psi))

A_ = tuple(diff(A, dot(y_gamma)) for y_gamma in y)
show(r'A =', A_)

ver = (0, A, 0)
hor = tuple((dq_n - ver_n).simplify() for dq_n, ver_n in zip(dq, ver))
show(r'\mathrm{ver}_q v =', ver)
show(r'\mathrm{hor}_q v =', hor)

nu, = variables(r'\nu', t)

U_nu = U + nu ** 2 / I_lock / 2
show(r'U_\nu =', U_nu)

R_nu = L - A * nu
show(r'R_\nu =', R_nu)
R_nu = metric(hor, hor) / 2 - U_nu
show(r'R_\nu =', R_nu)

B = tuple(tuple(diff(A_[a], y[gamma]) - diff(A_[gamma], y[a])
                for a in (0,1)) for gamma in (0,1))
show(r'B_{\gamma a} =', B)

LD = tuple(diff(diff(R_nu, dot(y[gamma])), t) - diff(R_nu, y[gamma]) - nu * sum(B[gamma][a] * dot(y[a]) for a in (0,1)) for gamma in (0,1))
show_equations(LD)

sol = solve(LD, ddq[0], ddq[2])
F = sp.Matrix((dq[0], dq[2]) + tuple(sol[ddq_n].simplify() for ddq_n in (ddq[0], ddq[2])))
show('F =', F)
# Out:
# $\displaystyle \mathbb{I} =\frac{{{\ell}}^2 {m}}{4} + {m} {{r}}^2$
# $\displaystyle J_\mathrm{L} =\frac{\left({{\ell}}^2 \dot{{\psi}} + {{\ell}}^2 \dot{{\theta}} + 4 {{r}}^2 \dot{{\theta}}\right) {m}}{4}$
# $\displaystyle \mathcal{A} =\frac{\left({{\ell}}^2 \dot{{\psi}} + {{\ell}}^2 \dot{{\theta}} + 4 {{r}}^2 \dot{{\theta}}\right) {m}}{4 \left(\frac{{{\ell}}^2 {m}}{4} + {m} {{r}}^2\right)}$
# $\displaystyle A =\left( 0, \  \frac{{{\ell}}^2 {m}}{4 \left(\frac{{{\ell}}^2 {m}}{4} + {m} {{r}}^2\right)}\right)$
# $\displaystyle \mathrm{ver}_q v =\left( 0, \  \frac{\left({{\ell}}^2 \dot{{\psi}} + {{\ell}}^2 \dot{{\theta}} + 4 {{r}}^2 \dot{{\theta}}\right) {m}}{4 \left(\frac{{{\ell}}^2 {m}}{4} + {m} {{r}}^2\right)}, \  0\right)$
# $\displaystyle \mathrm{hor}_q v =\left( \dot{{r}}, \  - \frac{{{\ell}}^2 \dot{{\psi}}}{{{\ell}}^2 + 4 {{r}}^2}, \  \dot{{\psi}}\right)$
# $\displaystyle U_\nu =- \left(\frac{1}{\sqrt{{{\ell}}^2 + 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} + \frac{1}{\sqrt{{{\ell}}^2 - 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}}\right) {\mu} {m} + \frac{{{\nu}}^2}{2 \left(\frac{{{\ell}}^2 {m}}{4} + {m} {{r}}^2\right)}$
# $\displaystyle R_\nu =\left(\frac{1}{\sqrt{{{\ell}}^2 + 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} + \frac{1}{\sqrt{{{\ell}}^2 - 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}}\right) {\mu} {m} + \frac{\left({{\ell}}^2 \dot{{\psi}}^{2} + 2 {{\ell}}^2 \dot{{\psi}} \dot{{\theta}} + {{\ell}}^2 \dot{{\theta}}^{2} + 4 {{r}}^2 \dot{{\theta}}^{2} + 4 \dot{{r}}^{2}\right) {m}}{8} - \frac{\left({{\ell}}^2 \dot{{\psi}} + {{\ell}}^2 \dot{{\theta}} + 4 {{r}}^2 \dot{{\theta}}\right) {\nu} {m}}{4 \left(\frac{{{\ell}}^2 {m}}{4} + {m} {{r}}^2\right)}$
# $\displaystyle R_\nu =\left(\frac{1}{\sqrt{{{\ell}}^2 + 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} + \frac{1}{\sqrt{{{\ell}}^2 - 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}}\right) {\mu} {m} + \frac{\left(\frac{{{\ell}}^2}{4} + {{r}}^2\right) {{\ell}}^4 {m} \dot{{\psi}}^{2}}{2 \left({{\ell}}^2 + 4 {{r}}^2\right)^{2}} + \frac{{{\ell}}^2 {m} \dot{{\psi}}^{2}}{8} + \frac{{m} \dot{{r}}^{2}}{2} - \frac{{{\ell}}^4 {m} \dot{{\psi}}^{2}}{4 \left({{\ell}}^2 + 4 {{r}}^2\right)} - \frac{{{\nu}}^2}{2 \left(\frac{{{\ell}}^2 {m}}{4} + {m} {{r}}^2\right)}$
# $\displaystyle B_{\gamma a} =\left( \left( 0, \  - \frac{{{\ell}}^2 {{m}}^2 {r}}{2 \left(\frac{{{\ell}}^2 {m}}{4} + {m} {{r}}^2\right)^{2}}\right), \  \left( \frac{{{\ell}}^2 {{m}}^2 {r}}{2 \left(\frac{{{\ell}}^2 {m}}{4} + {m} {{r}}^2\right)^{2}}, \  0\right)\right)$
# $\displaystyle \begin{cases}- \left(\frac{- 2 {\ell} \cos{\left({\psi} \right)} - 4 {r}}{\left({{\ell}}^2 + 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2\right)^{\frac{3}{2}}} + \frac{2 {\ell} \cos{\left({\psi} \right)} - 4 {r}}{\left({{\ell}}^2 - 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2\right)^{\frac{3}{2}}}\right) {\mu} {m} + \frac{8 \left(\frac{{{\ell}}^2}{4} + {{r}}^2\right) {{\ell}}^4 {m} {r} \dot{{\psi}}^{2}}{\left({{\ell}}^2 + 4 {{r}}^2\right)^{3}} + {m} \ddot{{r}} - \frac{3 {{\ell}}^4 {m} {r} \dot{{\psi}}^{2}}{\left({{\ell}}^2 + 4 {{r}}^2\right)^{2}} + \frac{{{\ell}}^2 {\nu} {{m}}^2 {r} \dot{{\psi}}}{2 \left(\frac{{{\ell}}^2 {m}}{4} + {m} {{r}}^2\right)^{2}} - \frac{{{\nu}}^2 {m} {r}}{\left(\frac{{{\ell}}^2 {m}}{4} + {m} {{r}}^2\right)^{2}} = 0\\- \left(\frac{2 {\ell} {r} \sin{\left({\psi} \right)}}{\left({{\ell}}^2 + 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2\right)^{\frac{3}{2}}} - \frac{2 {\ell} {r} \sin{\left({\psi} \right)}}{\left({{\ell}}^2 - 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2\right)^{\frac{3}{2}}}\right) {\mu} {m} + \frac{\left(\frac{{{\ell}}^2}{4} + {{r}}^2\right) {{\ell}}^4 {m} \ddot{{\psi}}}{\left({{\ell}}^2 + 4 {{r}}^2\right)^{2}} - \frac{16 \left(\frac{{{\ell}}^2}{4} + {{r}}^2\right) {{\ell}}^4 {m} {r} \dot{{\psi}} \dot{{r}}}{\left({{\ell}}^2 + 4 {{r}}^2\right)^{3}} + \frac{{{\ell}}^2 {m} \ddot{{\psi}}}{4} - \frac{{{\ell}}^4 {m} \ddot{{\psi}}}{2 \left({{\ell}}^2 + 4 {{r}}^2\right)} + \frac{6 {{\ell}}^4 {m} {r} \dot{{\psi}} \dot{{r}}}{\left({{\ell}}^2 + 4 {{r}}^2\right)^{2}} - \frac{{{\ell}}^2 {\nu} {{m}}^2 {r} \dot{{r}}}{2 \left(\frac{{{\ell}}^2 {m}}{4} + {m} {{r}}^2\right)^{2}} = 0\\\end{cases}$
# $\displaystyle F =\left[\begin{matrix}\dot{{r}}\\\dot{{\psi}}\\\frac{{{\ell}}^8 {{m}}^2 {r} \dot{{\psi}}^{2} - 8 {{\ell}}^6 {\nu} {m} {r} \dot{{\psi}} + 16 {{\ell}}^6 {{m}}^2 {{r}}^3 \sin^{2}{\left({\psi} \right)} \dot{{\psi}}^{2} - 8 {{\ell}}^6 {{m}}^2 {{r}}^3 \dot{{\psi}}^{2} + 16 {{\ell}}^4 {{\nu}}^2 {r} - 128 {{\ell}}^4 {\nu} {m} {{r}}^3 \sin^{2}{\left({\psi} \right)} \dot{{\psi}} + 64 {{\ell}}^4 {\nu} {m} {{r}}^3 \dot{{\psi}} + 16 {{\ell}}^4 {{m}}^2 {{r}}^5 \dot{{\psi}}^{2} + 256 {{\ell}}^2 {{\nu}}^2 {{r}}^3 \sin^{2}{\left({\psi} \right)} - 128 {{\ell}}^2 {{\nu}}^2 {{r}}^3 - 128 {{\ell}}^2 {\nu} {m} {{r}}^5 \dot{{\psi}} + 256 {{\nu}}^2 {{r}}^5 - \frac{2 {{\ell}}^7 {\mu} {{m}}^2 \cos{\left({\psi} \right)}}{\sqrt{{{\ell}}^2 + 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} - \frac{8 {{\ell}}^6 {\mu} {{m}}^2 {r} \sin^{2}{\left({\psi} \right)}}{\sqrt{{{\ell}}^2 + 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} + \frac{4 {{\ell}}^6 {\mu} {{m}}^2 {r}}{\sqrt{{{\ell}}^2 + 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} - \frac{8 {{\ell}}^5 {\mu} {{m}}^2 {{r}}^2 \cos{\left({\psi} \right)}}{\sqrt{{{\ell}}^2 + 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} - \frac{64 {{\ell}}^4 {\mu} {{m}}^2 {{r}}^3 \sin^{2}{\left({\psi} \right)}}{\sqrt{{{\ell}}^2 + 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} + \frac{16 {{\ell}}^4 {\mu} {{m}}^2 {{r}}^3}{\sqrt{{{\ell}}^2 + 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} + \frac{32 {{\ell}}^3 {\mu} {{m}}^2 {{r}}^4 \cos{\left({\psi} \right)}}{\sqrt{{{\ell}}^2 + 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} - \frac{128 {{\ell}}^2 {\mu} {{m}}^2 {{r}}^5 \sin^{2}{\left({\psi} \right)}}{\sqrt{{{\ell}}^2 + 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} - \frac{64 {{\ell}}^2 {\mu} {{m}}^2 {{r}}^5}{\sqrt{{{\ell}}^2 + 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} + \frac{128 {\ell} {\mu} {{m}}^2 {{r}}^6 \cos{\left({\psi} \right)}}{\sqrt{{{\ell}}^2 + 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} - \frac{256 {\mu} {{m}}^2 {{r}}^7}{\sqrt{{{\ell}}^2 + 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} + \frac{2 {{\ell}}^7 {\mu} {{m}}^2 \cos{\left({\psi} \right)}}{\sqrt{{{\ell}}^2 - 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} - \frac{8 {{\ell}}^6 {\mu} {{m}}^2 {r} \sin^{2}{\left({\psi} \right)}}{\sqrt{{{\ell}}^2 - 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} + \frac{4 {{\ell}}^6 {\mu} {{m}}^2 {r}}{\sqrt{{{\ell}}^2 - 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} + \frac{8 {{\ell}}^5 {\mu} {{m}}^2 {{r}}^2 \cos{\left({\psi} \right)}}{\sqrt{{{\ell}}^2 - 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} - \frac{64 {{\ell}}^4 {\mu} {{m}}^2 {{r}}^3 \sin^{2}{\left({\psi} \right)}}{\sqrt{{{\ell}}^2 - 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} + \frac{16 {{\ell}}^4 {\mu} {{m}}^2 {{r}}^3}{\sqrt{{{\ell}}^2 - 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} - \frac{32 {{\ell}}^3 {\mu} {{m}}^2 {{r}}^4 \cos{\left({\psi} \right)}}{\sqrt{{{\ell}}^2 - 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} - \frac{128 {{\ell}}^2 {\mu} {{m}}^2 {{r}}^5 \sin^{2}{\left({\psi} \right)}}{\sqrt{{{\ell}}^2 - 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} - \frac{64 {{\ell}}^2 {\mu} {{m}}^2 {{r}}^5}{\sqrt{{{\ell}}^2 - 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} - \frac{128 {\ell} {\mu} {{m}}^2 {{r}}^6 \cos{\left({\psi} \right)}}{\sqrt{{{\ell}}^2 - 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}} - \frac{256 {\mu} {{m}}^2 {{r}}^7}{\sqrt{{{\ell}}^2 - 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2}}}{\left({{\ell}}^2 + 4 {{r}}^2\right)^{2} \left({{\ell}}^4 + 16 {{\ell}}^2 {{r}}^2 \sin^{2}{\left({\psi} \right)} - 8 {{\ell}}^2 {{r}}^2 + 16 {{r}}^4\right) {{m}}^2}\\\frac{2 \left(- \sqrt{{{\ell}}^2 - 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2} \sqrt{{{\ell}}^2 + 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2} {{\ell}}^7 {m} \dot{{\psi}} \dot{{r}} + 4 \sqrt{{{\ell}}^2 - 4 {\ell} {r} \cos{\lef ...

# %%
import spb

equib = {dq_n: 0 for dq_n in dq}
LD_eq = tuple(LD_n.subs(equib).simplify() for LD_n in LD)
show_equations(LD_eq)

derivatives = (
    (r'\frac{\partial^2 U_\nu}{\partial r^2}', diff(U_nu, r, 2)),
    (r'\frac{\partial^2 U_\nu}{\partial \psi^2}', diff(U_nu, psi, 2)),
    (r'\frac{\partial^2 U_\nu}{\partial r \partial \psi}', diff(U_nu, r, psi)),
)

equib1 = {psi: 0}
LD_eq1 = tuple(LD_n.subs(equib1).simplify() for LD_n in LD_eq)
show_equations(LD_eq1)
nu2 = simplify(solve(LD_eq1[0], nu**2)[0])
show(r'\nu^2 =', nu2)

for label, derivative in derivatives:
    show(label + ' =', derivative.subs(equib1).subs(nu**2, nu2).simplify())

spb.plot(derivatives[0][1].subs(equib1).subs(nu**2, nu2).subs({l: 1, m: 1, mu: 1}), (r, 1, 20))
spb.plot(derivatives[1][1].subs(equib1).subs(nu**2, nu2).subs({l: 1, m: 1, mu: 1}), (r, 1, 20))

equib2 = {psi: pi/2}
LD_eq2 = tuple(LD_n.subs(equib2).simplify() for LD_n in LD_eq)
show_equations(LD_eq2)
nu2 = simplify(solve(LD_eq2[0], nu**2)[0])
show(r'\nu^2 =', nu2)

for label, derivative in derivatives:
    show(label + ' =', derivative.subs(equib2).subs(nu**2, nu2).simplify())

spb.plot(derivatives[0][1].subs(equib2).subs(nu**2, nu2).subs({l: 1, m: 1, mu: 1}), (r, 1, 20))

Jac = sp.simplify(F.jacobian(y + dy).subs(equib).subs(equib2).subs(nu**2, nu2))
show('J =', Jac)
lambda_, = variables(r'\lambda')
eigen_eq = (Jac - sp.eye(4) * lambda_).det("berkowitz").subs(nu**2, nu2).simplify()
show(eigen_eq)

sol = sp.solve(eigen_eq, lambda_)
for s in sol:
    show(r'\lambda =', s.simplify())
# Out:
# $\displaystyle \begin{cases}\frac{2 {\ell} {\mu} {m} \cos{\left({\psi} \right)}}{\left({{\ell}}^2 + 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2\right)^{\frac{3}{2}}} + \frac{4 {\mu} {m} {r}}{\left({{\ell}}^2 + 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2\right)^{\frac{3}{2}}} - \frac{2 {\ell} {\mu} {m} \cos{\left({\psi} \right)}}{\left({{\ell}}^2 - 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2\right)^{\frac{3}{2}}} + \frac{4 {\mu} {m} {r}}{\left({{\ell}}^2 - 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2\right)^{\frac{3}{2}}} - \frac{16 {{\nu}}^2 {r}}{\left({{\ell}}^2 + 4 {{r}}^2\right)^{2} {m}} = 0\\- \left(\frac{2 {\ell} {r} \sin{\left({\psi} \right)}}{\left({{\ell}}^2 + 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2\right)^{\frac{3}{2}}} - \frac{2 {\ell} {r} \sin{\left({\psi} \right)}}{\left({{\ell}}^2 - 4 {\ell} {r} \cos{\left({\psi} \right)} + 4 {{r}}^2\right)^{\frac{3}{2}}}\right) {\mu} {m} = 0\\\end{cases}$
# $\displaystyle \begin{cases}\frac{2 {\ell} {\mu} {m}}{\left({{\ell}}^2 + 4 {\ell} {r} + 4 {{r}}^2\right)^{\frac{3}{2}}} + \frac{4 {\mu} {m} {r}}{\left({{\ell}}^2 + 4 {\ell} {r} + 4 {{r}}^2\right)^{\frac{3}{2}}} - \frac{2 {\ell} {\mu} {m}}{\left({{\ell}}^2 - 4 {\ell} {r} + 4 {{r}}^2\right)^{\frac{3}{2}}} + \frac{4 {\mu} {m} {r}}{\left({{\ell}}^2 - 4 {\ell} {r} + 4 {{r}}^2\right)^{\frac{3}{2}}} - \frac{16 {{\nu}}^2 {r}}{\left({{\ell}}^2 + 4 {{r}}^2\right)^{2} {m}} = 0\\\text{True}\\\end{cases}$
# $\displaystyle \nu^2 =\frac{\left({{\ell}}^2 + 4 {{r}}^2\right)^{2} {\ell} {\mu} {{m}}^2}{8 \left({{\ell}}^2 + 4 {\ell} {r} + 4 {{r}}^2\right)^{\frac{3}{2}} {r}} + \frac{\left({{\ell}}^2 + 4 {{r}}^2\right)^{2} {\mu} {{m}}^2}{4 \left({{\ell}}^2 + 4 {\ell} {r} + 4 {{r}}^2\right)^{\frac{3}{2}}} - \frac{\left({{\ell}}^2 + 4 {{r}}^2\right)^{2} {\ell} {\mu} {{m}}^2}{8 \left({{\ell}}^2 - 4 {\ell} {r} + 4 {{r}}^2\right)^{\frac{3}{2}} {r}} + \frac{\left({{\ell}}^2 + 4 {{r}}^2\right)^{2} {\mu} {{m}}^2}{4 \left({{\ell}}^2 - 4 {\ell} {r} + 4 {{r}}^2\right)^{\frac{3}{2}}}$
# $\displaystyle \frac{\partial^2 U_\nu}{\partial r^2} =\frac{2 \left(\sqrt{{{\ell}}^2 - 4 {\ell} {r} + 4 {{r}}^2} {{\ell}}^7 + 2 \sqrt{{{\ell}}^2 - 4 {\ell} {r} + 4 {{r}}^2} {{\ell}}^6 {r} - 36 \sqrt{{{\ell}}^2 - 4 {\ell} {r} + 4 {{r}}^2} {{\ell}}^5 {{r}}^2 - 200 \sqrt{{{\ell}}^2 - 4 {\ell} {r} + 4 {{r}}^2} {{\ell}}^4 {{r}}^3 - 400 \sqrt{{{\ell}}^2 - 4 {\ell} {r} + 4 {{r}}^2} {{\ell}}^3 {{r}}^4 - 288 \sqrt{{{\ell}}^2 - 4 {\ell} {r} + 4 {{r}}^2} {{\ell}}^2 {{r}}^5 + 64 \sqrt{{{\ell}}^2 - 4 {\ell} {r} + 4 {{r}}^2} {\ell} {{r}}^6 + 128 \sqrt{{{\ell}}^2 - 4 {\ell} {r} + 4 {{r}}^2} {{r}}^7 - \sqrt{{{\ell}}^2 + 4 {\ell} {r} + 4 {{r}}^2} {{\ell}}^7 + 2 \sqrt{{{\ell}}^2 + 4 {\ell} {r} + 4 {{r}}^2} {{\ell}}^6 {r} + 36 \sqrt{{{\ell}}^2 + 4 {\ell} {r} + 4 {{r}}^2} {{\ell}}^5 {{r}}^2 - 200 \sqrt{{{\ell}}^2 + 4 {\ell} {r} + 4 {{r}}^2} {{\ell}}^4 {{r}}^3 + 400 \sqrt{{{\ell}}^2 + 4 {\ell} {r} + 4 {{r}}^2} {{\ell}}^3 {{r}}^4 - 288 \sqrt{{{\ell}}^2 + 4 {\ell} {r} + 4 {{r}}^2} {{\ell}}^2 {{r}}^5 - 64 \sqrt{{{\ell}}^2 + 4 {\ell} {r} + 4 {{r}}^2} {\ell} {{r}}^6 + 128 \sqrt{{{\ell}}^2 + 4 {\ell} {r} + 4 {{r}}^2} {{r}}^7\right) {\mu} {m}}{\left({{\ell}}^10 - 12 {{\ell}}^8 {{r}}^2 + 32 {{\ell}}^6 {{r}}^4 + 128 {{\ell}}^4 {{r}}^6 - 768 {{\ell}}^2 {{r}}^8 + 1024 {{r}}^10\right) {r}}$
# $\displaystyle \frac{\partial^2 U_\nu}{\partial \psi^2} =- \frac{2 {\ell} {\mu} {m} {r}}{\left({{\ell}}^2 + 4 {\ell} {r} + 4 {{r}}^2\right)^{\frac{3}{2}}} + \frac{2 {\ell} {\mu} {m} {r}}{\left({{\ell}}^2 - 4 {\ell} {r} + 4 {{r}}^2\right)^{\frac{3}{2}}}$
# $\displaystyle \frac{\partial^2 U_\nu}{\partial r \partial \psi} =0$
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# $\displaystyle \begin{cases}- \frac{16 {{\nu}}^2 {r}}{\left({{\ell}}^2 + 4 {{r}}^2\right)^{2} {m}} + \frac{8 {\mu} {m} {r}}{\left({{\ell}}^2 + 4 {{r}}^2\right)^{\frac{3}{2}}} = 0\\\text{True}\\\end{cases}$
# $\displaystyle \nu^2 =\frac{\sqrt{{{\ell}}^2 + 4 {{r}}^2} {\mu} {{m}}^2}{2}$
# $\displaystyle \frac{\partial^2 U_\nu}{\partial r^2} =\frac{32 {\mu} {m} {{r}}^2}{\left({{\ell}}^2 + 4 {{r}}^2\right)^{\frac{5}{2}}}$
# $\displaystyle \frac{\partial^2 U_\nu}{\partial \psi^2} =- \frac{24 {{\ell}}^2 {\mu} {m} {{r}}^2}{\left({{\ell}}^2 + 4 {{r}}^2\right)^{\frac{5}{2}}}$
# $\displaystyle \frac{\partial^2 U_\nu}{\partial r \partial \psi} =0$
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# $\displaystyle J =\left[\begin{matrix}0 & 0 & 1 & 0\\0 & 0 & 0 & 1\\- \frac{32 {\mu} {{r}}^2}{\sqrt{{{\ell}}^2 + 4 {{r}}^2} \left({{\ell}}^4 + 8 {{\ell}}^2 {{r}}^2 + 16 {{r}}^4\right)} & 0 & 0 & - \frac{8 {{\ell}}^2 {\nu} {r}}{\left({{\ell}}^4 + 8 {{\ell}}^2 {{r}}^2 + 16 {{r}}^4\right) {m}}\\0 & \frac{24 {\mu}}{\left({{\ell}}^2 + 4 {{r}}^2\right)^{\frac{3}{2}}} & \frac{8 {\nu}}{\left({{\ell}}^2 + 4 {{r}}^2\right) {m} {r}} & 0\end{matrix}\right]$
# $\displaystyle \frac{8 \sqrt{{{\ell}}^2 + 4 {{r}}^2} {{\ell}}^4 {{\lambda}}^2 {\mu} - 32 \sqrt{{{\ell}}^2 + 4 {{r}}^2} {{\ell}}^2 {{\lambda}}^2 {\mu} {{r}}^2 - 256 \sqrt{{{\ell}}^2 + 4 {{r}}^2} {{\lambda}}^2 {\mu} {{r}}^4 + {{\ell}}^8 {{\lambda}}^4 + 16 {{\ell}}^6 {{\lambda}}^4 {{r}}^2 + 96 {{\ell}}^4 {{\lambda}}^4 {{r}}^4 + 256 {{\ell}}^2 {{\lambda}}^4 {{r}}^6 + 256 {{\lambda}}^4 {{r}}^8 - 768 {{\mu}}^2 {{r}}^2}{{{\ell}}^8 + 16 {{\ell}}^6 {{r}}^2 + 96 {{\ell}}^4 {{r}}^4 + 256 {{\ell}}^2 {{r}}^6 + 256 {{r}}^8}$
# $\displaystyle \lambda =- 2 \sqrt{- \frac{\left(\sqrt{{{\ell}}^2 + 4 {{r}}^2} \sqrt{{{\ell}}^6 + 12 {{\ell}}^4 {{r}}^2 + 48 {{\ell}}^2 {{r}}^4 + 64 {{r}}^6} {{\ell}}^2 + 16 \sqrt{{{\ell}}^2 + 4 {{r}}^2} \sqrt{{{\ell}}^6 + 12 {{\ell}}^4 {{r}}^2 + 48 {{\ell}}^2 {{r}}^4 + 64 {{r}}^6} {{r}}^2 + {{\ell}}^6 - 48 {{\ell}}^2 {{r}}^4 - 128 {{r}}^6\right) {\mu}}{\sqrt{{{\ell}}^2 + 4 {{r}}^2} \left({{\ell}}^8 + 16 {{\ell}}^6 {{r}}^2 + 96 {{\ell}}^4 {{r}}^4 + 256 {{\ell}}^2 {{r}}^6 + 256 {{r}}^8\right)}}$
# $\displaystyle \lambda =2 \sqrt{\frac{\left(- \sqrt{{{\ell}}^2 + 4 {{r}}^2} \sqrt{{{\ell}}^6 + 12 {{\ell}}^4 {{r}}^2 + 48 {{\ell}}^2 {{r}}^4 + 64 {{r}}^6} {{\ell}}^2 - 16 \sqrt{{{\ell}}^2 + 4 {{r}}^2} \sqrt{{{\ell}}^6 + 12 {{\ell}}^4 {{r}}^2 + 48 {{\ell}}^2 {{r}}^4 + 64 {{r}}^6} {{r}}^2 - {{\ell}}^6 + 48 {{\ell}}^2 {{r}}^4 + 128 {{r}}^6\right) {\mu}}{\sqrt{{{\ell}}^2 + 4 {{r}}^2} \left({{\ell}}^8 + 16 {{\ell}}^6 {{r}}^2 + 96 {{\ell}}^4 {{r}}^4 + 256 {{\ell}}^2 {{r}}^6 + 256 {{r}}^8\right)}}$
# $\displaystyle \lambda =- 2 \sqrt{\frac{\left(\sqrt{{{\ell}}^2 + 4 {{r}}^2} \sqrt{{{\ell}}^6 + 12 {{\ell}}^4 {{r}}^2 + 48 {{\ell}}^2 {{r}}^4 + 64 {{r}}^6} {{\ell}}^2 + 16 \sqrt{{{\ell}}^2 + 4 {{r}}^2} \sqrt{{{\ell}}^6 + 12 {{\ell}}^4 {{r}}^2 + 48 {{\ell}}^2 {{r}}^4 + 64 {{r}}^6} {{r}}^2 - {{\ell}}^6 + 48 {{\ell}}^2 {{r}}^4 + 128 {{r}}^6\right) {\mu}}{\sqrt{{{\ell}}^2 + 4 {{r}}^2} \left({{\ell}}^8 + 16 {{\ell}}^6 {{r}}^2 + 96 {{\ell}}^4 {{r}}^4 + 256 {{\ell}}^2 {{r}}^6 + 256 {{r}}^8\right)}}$
# $\displaystyle \lambda =2 \sqrt{\frac{\left(\sqrt{{{\ell}}^2 + 4 {{r}}^2} \sqrt{{{\ell}}^6 + 12 {{\ell}}^4 {{r}}^2 + 48 {{\ell}}^2 {{r}}^4 + 64 {{r}}^6} {{\ell}}^2 + 16 \sqrt{{{\ell}}^2 + 4 {{r}}^2} \sqrt{{{\ell}}^6 + 12 {{\ell}}^4 {{r}}^2 + 48 {{\ell}}^2 {{r}}^4 + 64 {{r}}^6} {{r}}^2 - {{\ell}}^6 + 48 {{\ell}}^2 {{r}}^4 + 128 {{r}}^6\right) {\mu}}{\sqrt{{{\ell}}^2 + 4 {{r}}^2} \left({{\ell}}^8 + 16 {{\ell}}^6 {{r}}^2 + 96 {{\ell}}^4 {{r}}^4 + 256 {{\ell}}^2 {{r}}^6 + 256 {{r}}^8\right)}}$
