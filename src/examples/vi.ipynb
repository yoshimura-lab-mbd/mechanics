# %%
# %matplotlib widget
# %reset -f

from mechanics import *
from mechanics.lagrange import euler_lagrange_equation
import mechanics.space as space

t, = base_spaces('t')
def dot(f): return diff(f, t)

theta1, theta2 = q = variables(r'\theta_1 \theta_2', t, space=space.S)
dq = tuple(dot(q_n) for q_n in q)
ddq = tuple(dot(dq_n) for dq_n in dq)

g, m1, m2, l1, l2 = constants(r'g, m_1 m_2 \ell_1 \ell_2')

x1 = l1 * sin(theta1)
y1 = -l1 * cos(theta1)
x2 = x1 + l2 * sin(theta2)
y2 = y1 - l2 * cos(theta2)

U = m1 * g * y1 + m2 * g * y2
T = (m1 / 2 * (dot(x1)**2 + dot(y1)**2)
     + m2 / 2 * (dot(x2)**2 + dot(y2)**2)).simplify()
E = T + U
L = T - U
show('L =', L)

# EL = euler_lagrange_equation(L, q)
# show_equations(EL)

# F = solve(EL, ddq)
# show_equations(F)
# Out:
# $\displaystyle L =- \left(- {\ell_1} \cos{\left({\theta_1} \right)} - {\ell_2} \cos{\left({\theta_2} \right)}\right) {g} {m_2} + \frac{\left({{\ell_1}}^2 \dot{{\theta_1}}^{2} + 2 {\ell_1} {\ell_2} \cos{\left({\theta_1} - {\theta_2} \right)} \dot{{\theta_1}} \dot{{\theta_2}} + {{\ell_2}}^2 \dot{{\theta_2}}^{2}\right) {m_2}}{2} + \frac{{{\ell_1}}^2 {m_1} \dot{{\theta_1}}^{2}}{2} + {\ell_1} {g} {m_1} \cos{\left({\theta_1} \right)}$

# %%
theta1k, theta1k1, theta2k, theta2k1 = variables(r'\theta_{1,k} \theta_{1,k+1} \theta_{2,k} \theta_{2,k+1}', t, space=space.S)

# %%
h, = constants('h')

L_trapzoidal = (
    L.subs({
        theta1: theta1k,
        theta2: theta2k,
        dot(theta1): (theta1k1 - theta1k) / h,
        dot(theta2): (theta2k1 - theta2k) / h,
    }) +
    L.subs({
        theta1: theta1k1,
        theta2: theta2k1,
        dot(theta1): (theta1k1 - theta1k) / h,
        dot(theta2): (theta2k1 - theta2k) / h,
    })
) / 2 * h

L_midpoint = h * L.subs({
    theta1: (theta1k + theta1k1) / 2,
    theta2: (theta2k + theta2k1) / 2,
    dot(theta1): (theta1k1 - theta1k) / h,
    dot(theta2): (theta2k1 - theta2k) / h,
})

show(L_trapzoidal)
show(L_midpoint)
# Out:
# $\displaystyle \left(- \frac{\left(- {\ell_1} \cos{\left({\theta_{1,k+1}} \right)} - {\ell_2} \cos{\left({\theta_{2,k+1}} \right)}\right) {g} {m_2}}{2} - \frac{\left(- {\ell_1} \cos{\left({\theta_{1,k}} \right)} - {\ell_2} \cos{\left({\theta_{2,k}} \right)}\right) {g} {m_2}}{2} + \frac{\left({\theta_{1,k+1}} - {\theta_{1,k}}\right)^{2} {{\ell_1}}^2 {m_1}}{2 {{h}}^2} + \frac{\left(\frac{\left({\theta_{1,k+1}} - {\theta_{1,k}}\right)^{2} {{\ell_1}}^2}{{{h}}^2} + \frac{2 \left({\theta_{1,k+1}} - {\theta_{1,k}}\right) \left({\theta_{2,k+1}} - {\theta_{2,k}}\right) {\ell_1} {\ell_2} \cos{\left({\theta_{1,k+1}} - {\theta_{2,k+1}} \right)}}{{{h}}^2} + \frac{\left({\theta_{2,k+1}} - {\theta_{2,k}}\right)^{2} {{\ell_2}}^2}{{{h}}^2}\right) {m_2}}{4} + \frac{\left(\frac{\left({\theta_{1,k+1}} - {\theta_{1,k}}\right)^{2} {{\ell_1}}^2}{{{h}}^2} + \frac{2 \left({\theta_{1,k+1}} - {\theta_{1,k}}\right) \left({\theta_{2,k+1}} - {\theta_{2,k}}\right) {\ell_1} {\ell_2} \cos{\left({\theta_{1,k}} - {\theta_{2,k}} \right)}}{{{h}}^2} + \frac{\left({\theta_{2,k+1}} - {\theta_{2,k}}\right)^{2} {{\ell_2}}^2}{{{h}}^2}\right) {m_2}}{4} + \frac{{\ell_1} {g} {m_1} \cos{\left({\theta_{1,k+1}} \right)}}{2} + \frac{{\ell_1} {g} {m_1} \cos{\left({\theta_{1,k}} \right)}}{2}\right) {h}$
# $\displaystyle \left(- \left(- {\ell_1} \cos{\left(\frac{{\theta_{1,k+1}}}{2} + \frac{{\theta_{1,k}}}{2} \right)} - {\ell_2} \cos{\left(\frac{{\theta_{2,k+1}}}{2} + \frac{{\theta_{2,k}}}{2} \right)}\right) {g} {m_2} + \frac{\left({\theta_{1,k+1}} - {\theta_{1,k}}\right)^{2} {{\ell_1}}^2 {m_1}}{2 {{h}}^2} + \frac{\left(\frac{\left({\theta_{1,k+1}} - {\theta_{1,k}}\right)^{2} {{\ell_1}}^2}{{{h}}^2} + \frac{2 \left({\theta_{1,k+1}} - {\theta_{1,k}}\right) \left({\theta_{2,k+1}} - {\theta_{2,k}}\right) {\ell_1} {\ell_2} \cos{\left(\frac{{\theta_{1,k+1}}}{2} + \frac{{\theta_{1,k}}}{2} - \frac{{\theta_{2,k+1}}}{2} - \frac{{\theta_{2,k}}}{2} \right)}}{{{h}}^2} + \frac{\left({\theta_{2,k+1}} - {\theta_{2,k}}\right)^{2} {{\ell_2}}^2}{{{h}}^2}\right) {m_2}}{2} + {\ell_1} {g} {m_1} \cos{\left(\frac{{\theta_{1,k+1}}}{2} + \frac{{\theta_{1,k}}}{2} \right)}\right) {h}$

# %%
show(L_trapzoidal.simplify())
show(L_midpoint.simplify())
# Out:
# $\displaystyle \frac{2 \left({\theta_{1,k+1}} - {\theta_{1,k}}\right)^{2} {{\ell_1}}^2 {m_1} + \left(\left({\theta_{1,k+1}} - {\theta_{1,k}}\right)^{2} {{\ell_1}}^2 + 2 \left({\theta_{1,k+1}} - {\theta_{1,k}}\right) \left({\theta_{2,k+1}} - {\theta_{2,k}}\right) {\ell_1} {\ell_2} \cos{\left({\theta_{1,k+1}} - {\theta_{2,k+1}} \right)} + \left({\theta_{2,k+1}} - {\theta_{2,k}}\right)^{2} {{\ell_2}}^2\right) {m_2} + \left(\left({\theta_{1,k+1}} - {\theta_{1,k}}\right)^{2} {{\ell_1}}^2 + 2 \left({\theta_{1,k+1}} - {\theta_{1,k}}\right) \left({\theta_{2,k+1}} - {\theta_{2,k}}\right) {\ell_1} {\ell_2} \cos{\left({\theta_{1,k}} - {\theta_{2,k}} \right)} + \left({\theta_{2,k+1}} - {\theta_{2,k}}\right)^{2} {{\ell_2}}^2\right) {m_2} + 2 \left(\left({\ell_1} \cos{\left({\theta_{1,k+1}} \right)} + {\ell_2} \cos{\left({\theta_{2,k+1}} \right)}\right) {m_2} + \left({\ell_1} \cos{\left({\theta_{1,k}} \right)} + {\ell_2} \cos{\left({\theta_{2,k}} \right)}\right) {m_2} + {\ell_1} {m_1} \cos{\left({\theta_{1,k+1}} \right)} + {\ell_1} {m_1} \cos{\left({\theta_{1,k}} \right)}\right) {g} {{h}}^2}{4 {h}}$
# $\displaystyle \frac{\left(\left({\ell_1} \cos{\left(\frac{{\theta_{1,k+1}}}{2} + \frac{{\theta_{1,k}}}{2} \right)} + {\ell_2} \cos{\left(\frac{{\theta_{2,k+1}}}{2} + \frac{{\theta_{2,k}}}{2} \right)}\right) {m_2} + {\ell_1} {m_1} \cos{\left(\frac{{\theta_{1,k+1}}}{2} + \frac{{\theta_{1,k}}}{2} \right)}\right) {g} {{h}}^2 + \frac{\left({\theta_{1,k+1}} - {\theta_{1,k}}\right)^{2} {{\ell_1}}^2 {m_1}}{2} + \frac{\left(\left({\theta_{1,k+1}} - {\theta_{1,k}}\right)^{2} {{\ell_1}}^2 + 2 \left({\theta_{1,k+1}} - {\theta_{1,k}}\right) \left({\theta_{2,k+1}} - {\theta_{2,k}}\right) {\ell_1} {\ell_2} \cos{\left(\frac{{\theta_{1,k+1}}}{2} + \frac{{\theta_{1,k}}}{2} - \frac{{\theta_{2,k+1}}}{2} - \frac{{\theta_{2,k}}}{2} \right)} + \left({\theta_{2,k+1}} - {\theta_{2,k}}\right)^{2} {{\ell_2}}^2\right) {m_2}}{2}}{{h}}$

# %%
show(L_trapzoidal.expand(trig=True))
show(L_midpoint.expand(trig=True))
# Out:
# $\displaystyle \frac{{{\ell_1}}^2 {{\theta_{1,k+1}}}^2 {m_1}}{2 {h}} + \frac{{{\ell_1}}^2 {{\theta_{1,k+1}}}^2 {m_2}}{2 {h}} - \frac{{{\ell_1}}^2 {\theta_{1,k+1}} {\theta_{1,k}} {m_1}}{{h}} - \frac{{{\ell_1}}^2 {\theta_{1,k+1}} {\theta_{1,k}} {m_2}}{{h}} + \frac{{{\ell_1}}^2 {{\theta_{1,k}}}^2 {m_1}}{2 {h}} + \frac{{{\ell_1}}^2 {{\theta_{1,k}}}^2 {m_2}}{2 {h}} + \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k+1}} {m_2} \sin{\left({\theta_{1,k+1}} \right)} \sin{\left({\theta_{2,k+1}} \right)}}{2 {h}} + \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k+1}} {m_2} \sin{\left({\theta_{1,k}} \right)} \sin{\left({\theta_{2,k}} \right)}}{2 {h}} + \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k+1}} {m_2} \cos{\left({\theta_{1,k+1}} \right)} \cos{\left({\theta_{2,k+1}} \right)}}{2 {h}} + \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k+1}} {m_2} \cos{\left({\theta_{1,k}} \right)} \cos{\left({\theta_{2,k}} \right)}}{2 {h}} - \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k}} {m_2} \sin{\left({\theta_{1,k+1}} \right)} \sin{\left({\theta_{2,k+1}} \right)}}{2 {h}} - \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k}} {m_2} \sin{\left({\theta_{1,k}} \right)} \sin{\left({\theta_{2,k}} \right)}}{2 {h}} - \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k}} {m_2} \cos{\left({\theta_{1,k+1}} \right)} \cos{\left({\theta_{2,k+1}} \right)}}{2 {h}} - \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k}} {m_2} \cos{\left({\theta_{1,k}} \right)} \cos{\left({\theta_{2,k}} \right)}}{2 {h}} - \frac{{\ell_1} {\ell_2} {\theta_{1,k}} {\theta_{2,k+1}} {m_2} \sin{\left({\theta_{1,k+1}} \right)} \sin{\left({\theta_{2,k+1}} \right)}}{2 {h}} - \frac{{\ell_1} {\ell_2} {\theta_{1,k}} {\theta_{2,k+1}} {m_2} \sin{\left({\theta_{1,k}} \right)} \sin{\left({\theta_{2,k}} \right)}}{2 {h}} - \frac{{\ell_1} {\ell_2} {\theta_{1,k}} {\theta_{2,k+1}} {m_2} \cos{\left({\theta_{1,k+1}} \right)} \cos{\left({\theta_{2,k+1}} \right)}}{2 {h}} - \frac{{\ell_1} {\ell_2} {\theta_{1,k}} {\theta_{2,k+1}} {m_2} \cos{\left({\theta_{1,k}} \right)} \cos{\left({\theta_{2,k}} \right)}}{2 {h}} + \frac{{\ell_1} {\ell_2} {\theta_{1,k}} {\theta_{2,k}} {m_2} \sin{\left({\theta_{1,k+1}} \right)} \sin{\left({\theta_{2,k+1}} \right)}}{2 {h}} + \frac{{\ell_1} {\ell_2} {\theta_{1,k}} {\theta_{2,k}} {m_2} \sin{\left({\theta_{1,k}} \right)} \sin{\left({\theta_{2,k}} \right)}}{2 {h}} + \frac{{\ell_1} {\ell_2} {\theta_{1,k}} {\theta_{2,k}} {m_2} \cos{\left({\theta_{1,k+1}} \right)} \cos{\left({\theta_{2,k+1}} \right)}}{2 {h}} + \frac{{\ell_1} {\ell_2} {\theta_{1,k}} {\theta_{2,k}} {m_2} \cos{\left({\theta_{1,k}} \right)} \cos{\left({\theta_{2,k}} \right)}}{2 {h}} + \frac{{\ell_1} {g} {h} {m_1} \cos{\left({\theta_{1,k+1}} \right)}}{2} + \frac{{\ell_1} {g} {h} {m_1} \cos{\left({\theta_{1,k}} \right)}}{2} + \frac{{\ell_1} {g} {h} {m_2} \cos{\left({\theta_{1,k+1}} \right)}}{2} + \frac{{\ell_1} {g} {h} {m_2} \cos{\left({\theta_{1,k}} \right)}}{2} + \frac{{{\ell_2}}^2 {{\theta_{2,k+1}}}^2 {m_2}}{2 {h}} - \frac{{{\ell_2}}^2 {\theta_{2,k+1}} {\theta_{2,k}} {m_2}}{{h}} + \frac{{{\ell_2}}^2 {{\theta_{2,k}}}^2 {m_2}}{2 {h}} + \frac{{\ell_2} {g} {h} {m_2} \cos{\left({\theta_{2,k+1}} \right)}}{2} + \frac{{\ell_2} {g} {h} {m_2} \cos{\left({\theta_{2,k}} \right)}}{2}$
# $\displaystyle \frac{{{\ell_1}}^2 {{\theta_{1,k+1}}}^2 {m_1}}{2 {h}} + \frac{{{\ell_1}}^2 {{\theta_{1,k+1}}}^2 {m_2}}{2 {h}} - \frac{{{\ell_1}}^2 {\theta_{1,k+1}} {\theta_{1,k}} {m_1}}{{h}} - \frac{{{\ell_1}}^2 {\theta_{1,k+1}} {\theta_{1,k}} {m_2}}{{h}} + \frac{{{\ell_1}}^2 {{\theta_{1,k}}}^2 {m_1}}{2 {h}} + \frac{{{\ell_1}}^2 {{\theta_{1,k}}}^2 {m_2}}{2 {h}} + \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k+1}} {m_2} \sin{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \sin{\left(\frac{{\theta_{1,k}}}{2} \right)} \sin{\left(\frac{{\theta_{2,k+1}}}{2} \right)} \sin{\left(\frac{{\theta_{2,k}}}{2} \right)}}{{h}} - \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k+1}} {m_2} \sin{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \sin{\left(\frac{{\theta_{1,k}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k}}}{2} \right)}}{{h}} + \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k+1}} {m_2} \sin{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \sin{\left(\frac{{\theta_{2,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{1,k}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k}}}{2} \right)}}{{h}} + \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k+1}} {m_2} \sin{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \sin{\left(\frac{{\theta_{2,k}}}{2} \right)} \cos{\left(\frac{{\theta_{1,k}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k+1}}}{2} \right)}}{{h}} + \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k+1}} {m_2} \sin{\left(\frac{{\theta_{1,k}}}{2} \right)} \sin{\left(\frac{{\theta_{2,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k}}}{2} \right)}}{{h}} + \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k+1}} {m_2} \sin{\left(\frac{{\theta_{1,k}}}{2} \right)} \sin{\left(\frac{{\theta_{2,k}}}{2} \right)} \cos{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k+1}}}{2} \right)}}{{h}} - \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k+1}} {m_2} \sin{\left(\frac{{\theta_{2,k+1}}}{2} \right)} \sin{\left(\frac{{\theta_{2,k}}}{2} \right)} \cos{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{1,k}}}{2} \right)}}{{h}} + \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k+1}} {m_2} \cos{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{1,k}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k}}}{2} \right)}}{{h}} - \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k}} {m_2} \sin{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \sin{\left(\frac{{\theta_{1,k}}}{2} \right)} \sin{\left(\frac{{\theta_{2,k+1}}}{2} \right)} \sin{\left(\frac{{\theta_{2,k}}}{2} \right)}}{{h}} + \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k}} {m_2} \sin{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \sin{\left(\frac{{\theta_{1,k}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k}}}{2} \right)}}{{h}} - \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k}} {m_2} \sin{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \sin{\left(\frac{{\theta_{2,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{1,k}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k}}}{2} \right)}}{{h}} - \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k}} {m_2} \sin{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \sin{\left(\frac{{\theta_{2,k}}}{2} \right)} \cos{\left(\frac{{\theta_{1,k}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k+1}}}{2} \right)}}{{h}} - \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k}} {m_2} \sin{\left(\frac{{\theta_{1,k}}}{2} \right)} \sin{\left(\frac{{\theta_{2,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k}}}{2} \right)}}{{h}} - \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k}} {m_2} \sin{\left(\frac{{\theta_{1,k}}}{2} \right)} \sin{\left(\frac{{\theta_{2,k}}}{2} \right)} \cos{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k+1}}}{2} \right)}}{{h}} + \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k}} {m_2} \ ...

# %%
show((L_trapzoidal.expand(trig=True) - L_midpoint.expand(trig=True)).simplify())
# Out:
# $\displaystyle \frac{- {\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k+1}} {m_2} \sin{\left(\frac{{\theta_{1,k+1}}}{2} + \frac{{\theta_{1,k}}}{2} \right)} \sin{\left(\frac{{\theta_{2,k}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k+1}}}{2} \right)} - {\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k+1}} {m_2} \sin{\left(\frac{{\theta_{1,k+1}}}{2} - \frac{{\theta_{2,k}}}{2} \right)} \sin{\left(\frac{{\theta_{2,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{1,k}}}{2} \right)} + {\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k+1}} {m_2} \sin{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \sin{\left(\frac{{\theta_{1,k}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k+1}}}{2} + \frac{{\theta_{2,k}}}{2} \right)} + \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k+1}} {m_2} \cos{\left({\theta_{1,k+1}} - {\theta_{2,k+1}} \right)}}{2} - {\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k+1}} {m_2} \cos{\left(\frac{{\theta_{1,k}}}{2} - \frac{{\theta_{2,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k}}}{2} \right)} + \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k+1}} {m_2} \cos{\left({\theta_{1,k}} - {\theta_{2,k}} \right)}}{2} + {\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k}} {m_2} \sin{\left(\frac{{\theta_{1,k+1}}}{2} + \frac{{\theta_{1,k}}}{2} \right)} \sin{\left(\frac{{\theta_{2,k}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k+1}}}{2} \right)} - {\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k}} {m_2} \sin{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \sin{\left(\frac{{\theta_{1,k}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k}}}{2} \right)} + {\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k}} {m_2} \sin{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \sin{\left(\frac{{\theta_{2,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{1,k}}}{2} - \frac{{\theta_{2,k}}}{2} \right)} - {\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k}} {m_2} \sin{\left(\frac{{\theta_{2,k+1}}}{2} \right)} \sin{\left(\frac{{\theta_{2,k}}}{2} \right)} \cos{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{1,k}}}{2} \right)} - \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k}} {m_2} \cos{\left({\theta_{1,k+1}} - {\theta_{2,k+1}} \right)}}{2} + {\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k}} {m_2} \cos{\left(\frac{{\theta_{1,k}}}{2} - \frac{{\theta_{2,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k}}}{2} \right)} - \frac{{\ell_1} {\ell_2} {\theta_{1,k+1}} {\theta_{2,k}} {m_2} \cos{\left({\theta_{1,k}} - {\theta_{2,k}} \right)}}{2} + {\ell_1} {\ell_2} {\theta_{1,k}} {\theta_{2,k+1}} {m_2} \sin{\left(\frac{{\theta_{1,k+1}}}{2} + \frac{{\theta_{1,k}}}{2} \right)} \sin{\left(\frac{{\theta_{2,k}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k+1}}}{2} \right)} - {\ell_1} {\ell_2} {\theta_{1,k}} {\theta_{2,k+1}} {m_2} \sin{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \sin{\left(\frac{{\theta_{1,k}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k}}}{2} \right)} + {\ell_1} {\ell_2} {\theta_{1,k}} {\theta_{2,k+1}} {m_2} \sin{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \sin{\left(\frac{{\theta_{2,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{1,k}}}{2} - \frac{{\theta_{2,k}}}{2} \right)} - {\ell_1} {\ell_2} {\theta_{1,k}} {\theta_{2,k+1}} {m_2} \sin{\left(\frac{{\theta_{2,k+1}}}{2} \right)} \sin{\left(\frac{{\theta_{2,k}}}{2} \right)} \cos{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{1,k}}}{2} \right)} - \frac{{\ell_1} {\ell_2} {\theta_{1,k}} {\theta_{2,k+1}} {m_2} \cos{\left({\theta_{1,k+1}} - {\theta_{2,k+1}} \right)}}{2} + {\ell_1} {\ell_2} {\theta_{1,k}} {\theta_{2,k+1}} {m_2} \cos{\left(\frac{{\theta_{1,k}}}{2} - \frac{{\theta_{2,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{1,k+1}}}{2} \right)} \cos{\left(\frac{{\theta_{2,k}}}{2} \right)} - \frac{{\ell_1} {\ell_2} {\theta_{1,k}} {\theta_{2,k+1}} {m_2} \cos{\left({\theta_{1,k}} - {\theta_{2,k}} \right)}}{2} - {\ell_1} {\ell_2} {\theta ...
