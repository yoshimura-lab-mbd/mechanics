# %%
# %reset -f
# %load_ext autoreload
# %autoreload 2

import mechanics
from mechanics import *
from mechanics.lagrange import euler_lagrange_equation
import mechanics.space as space

t, = base_spaces('t')
def dot(f): return diff(f, t)

i, j = indices('i j')

x, y = q = variables('x y', i, t)
dq = tuple(dot(q_i) for q_i in q)
ddq = tuple(dot(dq_i) for dq_i in dq)

mu, N = constants(r'\mu N')
m, = constants('m', i)

U = Sum(m * mu / (sqrt((x[i] - x[j])**2 + (y[i] - y[j])**2)), 
        (i, 1, N), (j, i+1, N))
T = Sum(m / 2 * (dot(x)**2 + dot(y)**2), (i, 1, N))
E = T + U
L = T - U
show('L =', L)

EL = euler_lagrange_equation(L, q)
show_equations(EL)

# F = solve(EL, ddq)
# show_equations(F)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# $\displaystyle L =\sum_{i=1}^{{N}} \frac{\left(\dot{{x}}_{i}^{2} + \dot{{y}}_{i}^{2}\right) {m}_{i}}{2} - \sum_{\substack{1 \leq i \leq {N}\\i + 1 \leq j \leq {N}}} \frac{{\mu} {m}_{i}}{\sqrt{\left({x}_{i} - {x}_{j}\right)^{2} + \left({y}_{i} - {y}_{j}\right)^{2}}}$
# $\displaystyle \begin{cases}- \sum_{i=1}^{{N}} {m}_{i} \ddot{{x}}_{i} - \sum_{\substack{1 \leq i \leq {N}\\i + 1 \leq j \leq {N}}} \frac{\left(- {x}_{i} + {x}_{j}\right) {\mu} {m}_{i}}{\left(\left({x}_{i} - {x}_{j}\right)^{2} + \left({y}_{i} - {y}_{j}\right)^{2}\right)^{\frac{3}{2}}} + \sum_{i=1}^{{N}} 0 = 0\\- \sum_{i=1}^{{N}} {m}_{i} \ddot{{y}}_{i} - \sum_{\substack{1 \leq i \leq {N}\\i + 1 \leq j \leq {N}}} \frac{\left(- {y}_{i} + {y}_{j}\right) {\mu} {m}_{i}}{\left(\left({x}_{i} - {x}_{j}\right)^{2} + \left({y}_{i} - {y}_{j}\right)^{2}\right)^{\frac{3}{2}}} + \sum_{i=1}^{{N}} 0 = 0\\\end{cases}$

# %%
q
# Out:
# (x(i, t), y(i, t))

# %%
# from mechanics.integrator.runge_kutta import rk4_explicit
from mechanics.integrator.euler import euler_explicit

h, T = constants('h T')
i, = indices('i')
X, euler_step, d = euler_explicit(F, h, i)
show_equations(euler_step)

theta_1, theta_2 = d(q)
v_theta_1, v_theta_2 = d(dq)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 6
#       4 h, T = constants('h T')
#       5 i, = indices('i')
# ----> 6 X, euler_step, d = euler_explicit(F, h, i)
#       7 show_equations(euler_step)
#       9 theta_1, theta_2 = d(q)
#
# NameError: name 'F' is not defined

# %%
with Solver() as solver:
    solver.constants(m, l, index=(n, 1, 2))
    solver.constants(g, h, T)
    solver.variables(*X, indices=((n, 1, 2), (i, 0, T/h)))
    solver.functions('x_1', 'y_1', 'x_2', 'y_2', 'E', index=(i, 0, T/h))
    solver.inputs(*(x[:,0] for x in X))

    with solver.steps(i, 0, T/h) as step:
        step.solve_explicit(euler_step)
        step.calculate({
            'x_1': d(x_1), 'y_1': d(y_1), 'x_2': d(x_2), 'y_2': d(y_2), 'E': d(E)
            }, i)
# Out:
# Generating Fortran code in /var/folders/pr/76dm89zs5l96s1wmpwys3rqr0000gn/T/tmp02cpl887/generated.f90
# ======================== Compilation failed ========================
# Cannot use distutils backend with Python>=3.12, using meson backend instead.
# Using meson backend
# Will pass --lower to f2py
# See https://numpy.org/doc/stable/f2py/buildtools/meson.html
# Reading fortran codes...
# 	Reading file 'generated.f90' (format:free)
# {'before': '', 'this': 'use', 'after': ', intrinsic :: ieee_arithmetic '}
# Line #3 in generated.f90:"    use, intrinsic :: ieee_arithmetic "
# 	analyzeline: Could not crack the use statement.
# Post-processing...
# 	Block: generated
# 			Block: run_solver
# Applying post-processing hooks...
#   character_backward_compatibility_hook
# Post-processing (stage 2)...
# Building modules...
#     Building module "generated"...
#     Generating possibly empty wrappers"
#     Maybe empty "generated-f2pywrappers2.f90"
#     Maybe empty "generated-f2pywrappers.f"
# 		Creating wrapper for Fortran subroutine "run_solver"("run_solver")...
#         Constructing wrapper function "run_solver"...
#           status,message = run_solver(log_path,condition)
#     Wrote C/API module "generated" to file "./generatedmodule.c"
#     Fortran 90 wrappers are saved to "./generated-f2pywrappers2.f90"
# The Meson build system
# Version: 1.9.1
# Source dir: /private/var/folders/pr/76dm89zs5l96s1wmpwys3rqr0000gn/T/tmp02cpl887/build
# Build dir: /private/var/folders/pr/76dm89zs5l96s1wmpwys3rqr0000gn/T/tmp02cpl887/build/bbdir
# Build type: native build
# Project name: generated
# Project version: 0.1
# Fortran compiler for the host machine: gfortran (gcc 15.2.0 "GNU Fortran (Homebrew GCC 15.2.0) 15.2.0")
# Fortran linker for the host machine: gfortran ld64 1230.1
# C compiler for the host machine: cc (clang 17.0.0 "Apple clang version 17.0.0 (clang-1700.4.4.1)")
# C linker for the host machine: cc ld64 1230.1
# Host machine cpu family: aarch64
# Host machine cpu: aarch64
# Program /Users/fujihara/Develop/mechanics/.venv/bin/python found: YES (/Users/fujihara/Develop/mechanics/.venv/bin/python)
# Found pkg-config: YES (/opt/homebrew/bin/pkg-config) 2.5.1
# Run-time dependency python found: YES 3.13
# Library quadmath found: YES
# Build targets in project: 1
#
# Found ninja-1.13.1 at /opt/homebrew/bin/ninja
# INFO: autodetecting backend as ninja
# INFO: calculating backend command to run: /opt/homebrew/bin/ninja -C /private/var/folders/pr/76dm89zs5l96s1wmpwys3rqr0000gn/T/tmp02cpl887/build/bbdir
# ninja: Entering directory `/private/var/folders/pr/76dm89zs5l96s1wmpwys3rqr0000gn/T/tmp02cpl887/build/bbdir'
# [1/8] Compiling C object generated.cpython-313-darwin.so.p/generatedmodule.c.o
# [2/8] Scanning target generated.cpython-313-darwin for modules
# [3/8] Generating dynamic dependency information for target generated.cpython-313-darwin
# [4/8] Compiling C object generated.cpython-313-darwin.so.p/01791ba49764588fc5c1d6ee78f0cf9f665cbb80_.._.._f2py_src_fortranobject.c.o
# [5/8] Compiling Fortran object generated.cpython-313-darwin.so.p/generated.f90.o
# FAILED: [code=1] generated.cpython-313-darwin.so.p/generated.f90.o
# gfortran -Igenerated.cpython-313-darwin.so.p -I. -I.. -I/Users/fujihara/Develop/mechanics/.venv/lib/python3.13/site-packages/numpy/_core/include -I/Users/fujihara/Develop/mechanics/.venv/lib/python3.13/site-packages/numpy/f2py/src -I/opt/homebrew/opt/python@3.13/Frameworks/Python.framework/Versions/3.13/include/python3.13 -fvisibility=hidden -fdiagnostics-color=always -Wall -O3 -Wno-unused-dummy-argument -Jgenerated.cpython-313-darwin.so.p -o generated.cpython-313-darwin.so.p/generated.f90.o -c ../generated.f90
# ../generated.f90:59:13:
#
#    59 |     v_theta(n, 0) = condition(input_n)
#       |             1
# Error: Symbol 'n' at (1) has no IMPLICIT type
# [6/8] Compiling Fortran object generated.cpython-313-darwin.so.p/generated-f2pywrappers.f.o
# [7/8] Compiling Fortran object generated.cpython-313-darwin.so.p/generated-f2pywrappers2.f90.o
# ninja: build stopped: subcommand failed.
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/fujihara/Develop/mechanics/.venv/lib/python3.13/site-packages/numpy/f2py/__main__.py", line 5, in <module>
#     main()
#     ~~~~^^
#   File "/Users/fujihara/Develop/mechanics/.venv/lib/python3.13/site-packages/numpy/f2py/f2py2e.py", line 784, in main
#     run_compile()
#     ~~~~~~~~~~~^^
#   File "/Users/fujihara/Develop/mechanics/.venv/lib/python3.13/site-packages/numpy/f2py/f2py2e.py", line 756, in run_compile
#     builder.compile()
#     ~~~~~~~~~~~~~~~^^
#   File "/Users/fujihara/Develop/mechanics/.venv/lib/python3.13/site-packages/numpy/f2py/_backends/_meson.py", line 190, in compile
#     self.run_meson(self.build_dir)
#     ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "/Users/fujihara/Develop/mechanics/.venv/lib/python3.13/site-packages/numpy/f2py/_backends/_meson.py", line 185, in run_meson
#     self._run_subprocess_command(compile_command, build_dir)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/fujihara/Develop/mechanics/.venv/lib/python3.13/site-packages/numpy/f2py/_backends/_meson.py", line 179, in _run_subprocess_command
#     subprocess.run(command, cwd=cwd, check=True)
#     ~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.13/3.13.7/Frameworks/Python.framework/Versions/3.13/lib/python3.13/subprocess.py", line 577, in run
#     raise CalledProcessError(retcode, process.args,
#                              output=stdout, stderr=stderr)
# subprocess.CalledProcessError: Command '['meson', 'compile', '-C', 'bbdir']' returned non-zero exit status 1.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 with Solver() as solver:
#       2     solver.constants(m, l, index=(n, 1, 2))
#       3     solver.constants(g, h, T)
#
# File ~/Develop/mechanics/src/mechanics/solver.py:157, in Solver.__exit__(self, exc_type, exc_value, traceback)
#     154 code = self._generate(printer)
#     155 # print(code)
# --> 157 self._generated = self._compile_and_load(code)
#
# File ~/Develop/mechanics/src/mechanics/solver.py:375, in Solver._compile_and_load(self, source, libs)
#     373     print('======================== Compilation failed ========================')
#     374     print(ret.stdout.decode())
# --> 375     raise RuntimeError(f'Compilation failed with return code {ret.returncode}')
#     377 so_file = next(p for p in os.listdir(self._generate_dir) if p.startswith(generated_name) and p.endswith('.so'))
#     378 so_fullpath = os.path.join(self._generate_dir, so_file)
#
# RuntimeError: Compilation failed with return code 1

# %%
_ = solver.run({
    m: [1.0, 1.0], l: [1.0, 1.0], g: 1.0,
    h: 0.1, T: 1.0,
    theta_1[0]: 1.0, theta_2[0]: 1.0,
    v_theta_1[0]: 0.0, v_theta_2[0]: 0.0,
})
# Out:
#  Started
#  Completed
# Log data in: /var/folders/pr/76dm89zs5l96s1wmpwys3rqr0000gn/T/tmp5e_55onb/result.log, size=106

# %%
_
# Out:
# {m(n,): memmap([1., 1.]),
#  \ell(n,): memmap([1., 1.]),
#  g(): np.float64(1.0),
#  h(): np.float64(0.1),
#  T(): np.float64(1.0),
#  \theta(n, i): memmap([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#          [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]]),
#  v_\theta(n, i): memmap([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#          [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]]),
#  'x_1': memmap([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'y_1': memmap([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'x_2': memmap([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'y_2': memmap([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'E': memmap([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan])}
